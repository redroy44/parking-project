# %%
import os, sys
import random
import numpy as np
import glob


DATA_PATH = "data/PKLot/PKLotSegmented/"

all_images = [DATA_PATH+i for i in os.listdir(DATA_PATH)] # use this for full dataset

PARKING_LIST = ["PUC"]
CONDITION_LIST = ["Sunny"]

PARKING_LIST = ["PUC", "UFPR04", "UFPR05"]
CONDITION_LIST = ["Cloudy", "Rainy", "Sunny"]

# %%
def browse_dirs():
    dir_list = []
    for park in PARKING_LIST:
        for cond in CONDITION_LIST:
            dirs = glob.glob(os.path.join(DATA_PATH, park, cond, '*'))
            print("There are %d subdirectories in %s" % (len(dirs), os.path.join(DATA_PATH, park, cond)))
            dir_list.append(dirs)

    return dir_list

# %%
SPLIT = np.array([0.5, 0.8])

def split_dirs(dir_list):
    split_list = []
    for dirs in np.array(dir_list):
        #print("Split indices %s" % ((len(dirs)*SPLIT).astype(int)))
        split_list.append(np.array_split(np.array(dirs), (len(dirs)*SPLIT).astype(int)))

    return split_list

# %%
def create_dirs(dir_list):
    symlinks_list = ['data/symlinks/train', 'data/symlinks/validation', 'data/symlinks/test']
    if not os.path.exists('data/symlinks'):
        os.mkdir('data/symlinks')
    for d in symlinks_list:
        if not os.path.exists(d):
            os.mkdir(d)
        if not os.path.exists(os.path.join(d, "Occupied")):
            os.mkdir(os.path.join(d, "Occupied"))
        if not os.path.exists(os.path.join(d, "Empty")):
            os.mkdir(os.path.join(d, "Empty"))

    for dirs in dir_list:
        for i, data in enumerate(dirs):
            for d in data:
                print(symlinks_list[i], len(d))
                occupied_list = glob.glob(os.path.join(d, "Occupied", "*.jpg"), recursive=True)
                empty_list = glob.glob(os.path.join(d, "Empty", "*.jpg"), recursive=True)
                print("Empty class in %s is: %d"%(d, len(empty_list)))
                print("Occupied class in %s is: %d"%(d, len(occupied_list)))
                create_symlinks(occupied_list, d, symlinks_list[i])
                create_symlinks(empty_list, d, symlinks_list[i])

# %%
def create_symlinks(file_list, root_path, sym_path):
    file = file_list
    for file in file_list:
        dst = file.replace(root_path, sym_path)
        src = file
        if not os.path.exists(os.path.abspath(dst)):
            os.symlink(os.path.abspath(src), os.path.abspath(dst))

# %%
create_dirs(split_dirs(browse_dirs()))
# Out:
# There are 11 subdirectories in data/PKLot/PKLotSegmented/PUC/Cloudy
# There are 8 subdirectories in data/PKLot/PKLotSegmented/PUC/Rainy
# There are 25 subdirectories in data/PKLot/PKLotSegmented/PUC/Sunny
# There are 15 subdirectories in data/PKLot/PKLotSegmented/UFPR04/Cloudy
# There are 14 subdirectories in data/PKLot/PKLotSegmented/UFPR04/Rainy
# There are 20 subdirectories in data/PKLot/PKLotSegmented/UFPR04/Sunny
# There are 19 subdirectories in data/PKLot/PKLotSegmented/UFPR05/Cloudy
# There are 8 subdirectories in data/PKLot/PKLotSegmented/UFPR05/Rainy
# There are 25 subdirectories in data/PKLot/PKLotSegmented/UFPR05/Sunny
# data/symlinks/train 47
# Empty class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-16 is: 5382
# Occupied class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-16 is: 9114
# data/symlinks/train 47
# Empty class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-14 is: 14775
# Occupied class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-14 is: 125
# data/symlinks/train 47
# Empty class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-11-08 is: 4773
# Occupied class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-11-08 is: 11420
# data/symlinks/train 47
# Empty class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-12 is: 15398
# Occupied class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-12 is: 2
# data/symlinks/train 47
# Empty class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-05 is: 102
# Occupied class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-05 is: 898
# data/symlinks/validation 47
# Empty class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-31 is: 5553
# Occupied class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-31 is: 7945
# data/symlinks/validation 47
# Empty class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-13 is: 15063
# Occupied class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-13 is: 435
# data/symlinks/validation 47
# Empty class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-09-12 is: 1903
# Occupied class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-09-12 is: 3195
# data/symlinks/test 47
# Empty class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-11-11 is: 7881
# Occupied class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-11-11 is: 19
# data/symlinks/test 47
# Empty class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-09-28 is: 4039
# Occupied class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-09-28 is: 9158
# data/symlinks/test 47
# Empty class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-28 is: 15548
# Occupied class in data/PKLot/PKLotSegmented/PUC/Cloudy/2012-10-28 is: 52
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-10-25 is: 2893
# Occupied class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-10-25 is: 10704
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-09-21 is: 3685
# Occupied class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-09-21 is: 5811
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-10-11 is: 6056
# Occupied class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-10-11 is: 12432
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-10-26 is: 4706
# Occupied class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-10-26 is: 11185
# data/symlinks/validation 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-09-16 is: 2349
# Occupied class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-09-16 is: 51
# data/symlinks/validation 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-11-09 is: 5094
# Occupied class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-11-09 is: 10997
# data/symlinks/test 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-11-10 is: 3092
# Occupied class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-11-10 is: 2901
# data/symlinks/test 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-10-23 is: 76
# Occupied class in data/PKLot/PKLotSegmented/PUC/Rainy/2012-10-23 is: 1024
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-20 is: 5111
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-20 is: 9764
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-19 is: 4950
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-19 is: 8743
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-11 is: 956
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-11 is: 2615
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-10-27 is: 12742
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-10-27 is: 2857
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-11-07 is: 0
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-11-07 is: 176
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-27 is: 7
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-27 is: 1899
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-18 is: 5590
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-18 is: 9200
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-21 is: 1098
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-21 is: 2102
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-10-17 is: 2818
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-10-17 is: 3980
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-10-30 is: 0
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-10-30 is: 190
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-29 is: 1998
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-29 is: 2
# data/symlinks/train 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-14 is: 3227
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-14 is: 7849
# data/symlinks/validation 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-16 is: 11508
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-16 is: 392
# data/symlinks/validation 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-12 is: 3235
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-12 is: 5764
# data/symlinks/validation 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-11-11 is: 7595
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-11-11 is: 502
# data/symlinks/validation 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-17 is: 4843
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-17 is: 9853
# data/symlinks/validation 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-28 is: 1741
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-28 is: 57
# data/symlinks/validation 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-11-10 is: 7427
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-11-10 is: 2573
# data/symlinks/validation 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-11-20 is: 1012
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-11-20 is: 3388
# data/symlinks/validation 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-13 is: 5414
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-13 is: 6985
# data/symlinks/test 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-15 is: 9973
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-09-15 is: 4819
# data/symlinks/test 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-10-15 is: 15278
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-10-15 is: 422
# data/symlinks/test 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-10-29 is: 4986
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-10-29 is: 11107
# data/symlinks/test 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-11-06 is: 0
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-11-06 is: 139
# data/symlinks/test 46
# Empty class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-10-09 is: 117
# Occupied class in data/PKLot/PKLotSegmented/PUC/Sunny/2012-10-09 is: 1383
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-16 is: 186
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-16 is: 10
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-28 is: 3765
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-28 is: 42
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2013-01-22 is: 247
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2013-01-22 is: 2805
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2013-01-16 is: 2714
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2013-01-16 is: 1028
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2013-01-29 is: 52
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2013-01-29 is: 1569
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2013-01-20 is: 4424
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2013-01-20 is: 0
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-12 is: 4
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-12 is: 722
# data/symlinks/validation 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2013-01-15 is: 1661
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2013-01-15 is: 660
# data/symlinks/validation 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-15 is: 2057
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-15 is: 182
# data/symlinks/validation 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2013-01-19 is: 4252
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2013-01-19 is: 4
# data/symlinks/validation 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-14 is: 438
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-14 is: 3530
# data/symlinks/validation 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-27 is: 1506
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-27 is: 110
# data/symlinks/test 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-17 is: 24
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-17 is: 900
# data/symlinks/test 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-29 is: 2856
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-29 is: 0
# data/symlinks/test 50
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-22 is: 3591
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Cloudy/2012-12-22 is: 46
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-21 is: 70
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-21 is: 42
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-28 is: 504
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-28 is: 0
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2013-01-16 is: 77
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2013-01-16 is: 124
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2013-01-21 is: 228
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2013-01-21 is: 751
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-08 is: 560
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-08 is: 0
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-11 is: 6
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-11 is: 554
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-07 is: 3
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-07 is: 160
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-26 is: 1406
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-26 is: 22
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-15 is: 223
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-15 is: 1
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-14 is: 262
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-14 is: 296
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2013-01-18 is: 952
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2013-01-18 is: 165
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-29 is: 504
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-29 is: 0
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2013-01-17 is: 800
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2013-01-17 is: 137
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-19 is: 12
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Rainy/2012-12-19 is: 99
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-16 is: 658
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-16 is: 2050
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-21 is: 892
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-21 is: 2155
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2013-01-22 is: 240
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2013-01-22 is: 1297
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2013-01-21 is: 289
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2013-01-21 is: 3303
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2013-01-29 is: 44
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2013-01-29 is: 712
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-08 is: 3280
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-08 is: 105
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-13 is: 140
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-13 is: 3815
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-18 is: 171
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-18 is: 3629
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-11 is: 85
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-11 is: 1229
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-12 is: 134
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-12 is: 2490
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-07 is: 305
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-07 is: 892
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-26 is: 2349
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-26 is: 59
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-24 is: 4368
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-24 is: 0
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-20 is: 201
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-20 is: 3487
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-23 is: 4368
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-23 is: 0
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-17 is: 196
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-17 is: 2544
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-25 is: 3752
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-25 is: 0
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2013-01-18 is: 2514
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2013-01-18 is: 478
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2013-01-17 is: 2179
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2013-01-17 is: 1231
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-19 is: 169
# Occupied class in data/PKLot/PKLotSegmented/UFPR04/Sunny/2012-12-19 is: 2690
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-04-12 is: 5
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-04-12 is: 715
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-19 is: 276
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-19 is: 4842
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-16 is: 1640
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-16 is: 520
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-05 is: 225
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-05 is: 1415
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-02-26 is: 42
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-02-26 is: 2499
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-09 is: 5246
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-09 is: 633
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-03 is: 320
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-03 is: 0
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-02-22 is: 344
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-02-22 is: 536
# data/symlinks/train 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-02 is: 320
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-02 is: 0
# data/symlinks/validation 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-14 is: 572
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-14 is: 5306
# data/symlinks/validation 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-17 is: 5798
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-17 is: 2
# data/symlinks/validation 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-04-08 is: 58
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-04-08 is: 102
# data/symlinks/validation 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-04-14 is: 1887
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-04-14 is: 353
# data/symlinks/validation 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-20 is: 648
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-20 is: 3152
# data/symlinks/validation 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-15 is: 894
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-15 is: 4897
# data/symlinks/test 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-04-13 is: 3264
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-04-13 is: 967
# data/symlinks/test 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-18 is: 633
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-18 is: 1407
# data/symlinks/test 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-12 is: 551
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-12 is: 3578
# data/symlinks/test 50
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-13 is: 479
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Cloudy/2013-03-13 is: 2840
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-04-12 is: 246
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-04-12 is: 753
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-03-19 is: 367
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-03-19 is: 190
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-03-16 is: 806
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-03-16 is: 91
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-03-05 is: 16
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-03-05 is: 1342
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-02-26 is: 1
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-02-26 is: 79
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-03-20 is: 148
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-03-20 is: 1702
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-04-13 is: 1224
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-04-13 is: 16
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-03-13 is: 43
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Rainy/2013-03-13 is: 1905
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-12 is: 1338
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-12 is: 2302
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-16 is: 2260
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-16 is: 540
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-09 is: 1047
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-09 is: 4588
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-22 is: 921
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-22 is: 2677
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-05 is: 512
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-05 is: 2008
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-02-26 is: 19
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-02-26 is: 120
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-03 is: 5703
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-03 is: 0
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-02-28 is: 13
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-02-28 is: 387
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-10 is: 5915
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-10 is: 0
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-02-22 is: 891
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-02-22 is: 4387
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-02 is: 4829
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-02 is: 913
# data/symlinks/train 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-06 is: 576
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-06 is: 5263
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-15 is: 826
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-15 is: 4691
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-11 is: 1132
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-11 is: 4588
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-01 is: 218
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-01 is: 342
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-14 is: 1293
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-14 is: 1947
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-02-23 is: 5262
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-02-23 is: 898
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-10 is: 1227
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-10 is: 4489
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-16 is: 367
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-04-16 is: 1752
# data/symlinks/validation 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-18 is: 90
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-18 is: 3629
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-21 is: 903
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-21 is: 4936
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-11 is: 880
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-11 is: 4956
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-12 is: 21
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-12 is: 1658
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-02-24 is: 6056
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-02-24 is: 0
# data/symlinks/test 49
# Empty class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-13 is: 7
# Occupied class in data/PKLot/PKLotSegmented/UFPR05/Sunny/2013-03-13 is: 513
